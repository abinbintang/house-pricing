# %% [markdown]
# # House Prices Prediction

# %%
import pandas as pd
import numpy as np
from sklearn import metrics

# %%
test = pd.read_csv("test.csv")
train = pd.read_csv("train.csv")

# %%
train.isna().sum().sort_values(ascending=False)[0:14]
a = """LotFrontage
GarageType
GarageYrBlt
GarageFinish
GarageQual
GarageCond
BsmtFinType2
BsmtExposure
BsmtQual
BsmtCond
BsmtFinType1
MasVnrArea
MasVnrType
Electrical"""
b = a.split("\n")

# %%
train[b]
# Out:
#       LotFrontage GarageType  GarageYrBlt GarageFinish GarageQual GarageCond  \
# 0            65.0     Attchd       2003.0          RFn         TA         TA
# 1            80.0     Attchd       1976.0          RFn         TA         TA
# 2            68.0     Attchd       2001.0          RFn         TA         TA
# 3            60.0     Detchd       1998.0          Unf         TA         TA
# 4            84.0     Attchd       2000.0          RFn         TA         TA
# ...           ...        ...          ...          ...        ...        ...
# 1455         62.0     Attchd       1999.0          RFn         TA         TA
# 1456         85.0     Attchd       1978.0          Unf         TA         TA
# 1457         66.0     Attchd       1941.0          RFn         TA         TA
# 1458         68.0     Attchd       1950.0          Unf         TA         TA
# 1459         75.0     Attchd       1965.0          Fin         TA         TA
#
# ...

# %%
for i in b:
    print("train."+i+".fillna(train."+i+".mode()[0], inplace=True)")
# Out:
# train.LotFrontage.fillna(train.LotFrontage.mode()[0], inplace=True)
# train.GarageType.fillna(train.GarageType.mode()[0], inplace=True)
# train.GarageYrBlt.fillna(train.GarageYrBlt.mode()[0], inplace=True)
# train.GarageFinish.fillna(train.GarageFinish.mode()[0], inplace=True)
# train.GarageQual.fillna(train.GarageQual.mode()[0], inplace=True)
# train.GarageCond.fillna(train.GarageCond.mode()[0], inplace=True)
# train.BsmtFinType2.fillna(train.BsmtFinType2.mode()[0], inplace=True)
# train.BsmtExposure.fillna(train.BsmtExposure.mode()[0], inplace=True)
# train.BsmtQual.fillna(train.BsmtQual.mode()[0], inplace=True)
# train.BsmtCond.fillna(train.BsmtCond.mode()[0], inplace=True)
# train.BsmtFinType1.fillna(train.BsmtFinType1.mode()[0], inplace=True)
# train.MasVnrArea.fillna(train.MasVnrArea.mode()[0], inplace=True)
# train.MasVnrType.fillna(train.MasVnrType.mode()[0], inplace=True)
# train.Electrical.fillna(train.Electrical.mode()[0], inplace=True)

# %%
train.LotFrontage.fillna(train.LotFrontage.median(), inplace=True)
train.GarageType.fillna(train.GarageType.mode()[0], inplace=True)
train.GarageYrBlt.fillna(train.GarageYrBlt.median(), inplace=True)
train.GarageFinish.fillna(train.GarageFinish.mode()[0], inplace=True)
train.GarageQual.fillna(train.GarageQual.mode()[0], inplace=True)
train.GarageCond.fillna(train.GarageCond.mode()[0], inplace=True)
train.BsmtFinType2.fillna(train.BsmtFinType2.mode()[0], inplace=True)
train.BsmtExposure.fillna(train.BsmtExposure.mode()[0], inplace=True)
train.BsmtQual.fillna(train.BsmtQual.mode()[0], inplace=True)
train.BsmtCond.fillna(train.BsmtCond.mode()[0], inplace=True)
train.BsmtFinType1.fillna(train.BsmtFinType1.mode()[0], inplace=True)
train.MasVnrArea.fillna(train.MasVnrArea.median(), inplace=True)
train.MasVnrType.fillna(train.MasVnrType.mode()[0], inplace=True)
train.Electrical.fillna(train.Electrical.mode()[0], inplace=True)

# %% [markdown]
# 5 Fitur teratas memiliki jumlah kolom null lebih dari 40% dari data tersebut, maka diputuskan untuk dihapus

# %%
train.isna().sum().sort_values(ascending=False)
# Out:
# PoolQC         1453
# MiscFeature    1406
# Alley          1369
# Fence          1179
# FireplaceQu     690
#                ...
# MasVnrArea        0
# MasVnrType        0
# Exterior2nd       0
# Exterior1st       0
# SalePrice         0
# Length: 81, dtype: int64

# %%
train.drop(columns=["PoolQC", "MiscFeature", "Alley", "Fence", "FireplaceQu", "Id"], inplace=True)
# test.drop(columns=["PoolQC", "MiscFeature", "Alley", "Fence", "FireplaceQu"], inplace=True)

# %%
train.drop_duplicates()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
train.isna().sum().sort_values(ascending=False)
# Out:
# MSSubClass      0
# GarageYrBlt     0
# Fireplaces      0
# Functional      0
# TotRmsAbvGrd    0
#                ..
# MasVnrArea      0
# MasVnrType      0
# Exterior2nd     0
# Exterior1st     0
# SalePrice       0
# Length: 75, dtype: int64

# %%
df_cleaned = pd.get_dummies(train, drop_first=True)
df_cleaned.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLI  \
# 0          2003       196.0         706           0  ...               0
# 1          1976         0.0         978           0  ...               0
# 2          2002       162.0         486           0  ...               0
# 3          1970         0.0         216           0  ...               0
# 4          2000       350.0         655           0  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# ...

# %%
X =df_cleaned.drop("SalePrice", axis=1)
y = df_cleaned['SalePrice']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=101)

# %%
X_train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 1312          60         69.0     9572            8            5       1990
# 1408          70         60.0     7740            4            7       1910
# 1165          20         79.0     9541            7            5       2009
# 1346          20         69.0    20781            7            7       1968
# 399           60         65.0     8125            7            5       2006
# ...          ...          ...      ...          ...          ...        ...
# 1417          60         69.0    16545            8            5       1998
# 75           180         21.0     1596            4            5       1973
# 599          160         24.0     1950            6            6       1980
# 1361          20        124.0    16158            7            5       2005
# 863           20         70.0     7931            5            5       1959
#
# ...

# %%
X_test
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 1054          60         90.0    11367            8            5       2002
# 361           50         69.0     9144            5            5       1940
# 1282          20         61.0     8800            5            7       1977
# 161           60        110.0    13688            9            5       2003
# 515           20         94.0    12220           10            5       2009
# ...          ...          ...      ...          ...          ...        ...
# 249           50         69.0   159000            6            7       1958
# 467           70         79.0     9480            5            7       1942
# 650           60         65.0     8125            7            6       2007
# 48           190         33.0     4456            4            5       1920
# 454           90         63.0     9297            5            5       1976
#
# ...

# %% [markdown]
# Scaling dengan Standard Scaler

# %%
numerical_columns = train.select_dtypes(include=['number']).columns
cols = numerical_columns[0:-1]
cols
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train[cols])

X_train[cols] = scaler.transform(X_train[cols])
X_test[cols] = scaler.transform(X_test[cols])

# %% [markdown]
# ## Model Prediction

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

lin = LinearRegression()


lin.fit(X_train, y_train)

linear_res = lin.predict(X_test)

# %% [markdown]
# ### Lasso Regression

# %%
las = Lasso()
las.fit(X_train, y_train)
las_res = las.predict(X_test)
# Out:
# c:\Users\ABIN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.381e+08, tolerance: 6.450e+08
#   model = cd_fast.enet_coordinate_descent(

# %%
rid = Ridge()
rid.fit(X_train, y_train)
rid_res = rid.predict(X_test)

# %%
import math

print("MSE:", metrics.mean_squared_error(y_test, linear_res))
print("MAE:", metrics.mean_absolute_error(y_test, linear_res))
print("RMSE: ", math.sqrt(metrics.mean_squared_error(y_test, linear_res))) 
print("R-squared:", metrics.r2_score(y_test, linear_res))
# Out:
# MSE: 1.2322856338681734e+28
# MAE: 6533919672037.799
# RMSE:  111008361571017.4
# R-squared: -1.9582367572589757e+18
